# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://docs.deepnote.com/environment/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here apart from blacklisted packages that interfere with Deepnote (see above).
# if test -f requirements.txt
#   then
#     sed -i '/jedi/d;/jupyter/d;' ./requirements.txt
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install. This is the case with most projects."
# fi
# Out:
# Collecting lime==0.2.0.1
#   Downloading lime-0.2.0.1.tar.gz (275 kB)
# Collecting xgboost==1.5.2
#   Downloading xgboost-1.5.2-py3-none-manylinux2014_x86_64.whl (173.6 MB)
# Requirement already satisfied: matplotlib in /shared-libs/python3.7/py/lib/python3.7/site-packages (from lime==0.2.0.1->-r ./requirements.txt (line 1)) (3.5.1)
# Requirement already satisfied: numpy in /shared-libs/python3.7/py/lib/python3.7/site-packages (from lime==0.2.0.1->-r ./requirements.txt (line 1)) (1.21.5)
# Requirement already satisfied: scipy in /shared-libs/python3.7/py/lib/python3.7/site-packages (from lime==0.2.0.1->-r ./requirements.txt (line 1)) (1.7.3)
# Requirement already satisfied: tqdm in /shared-libs/python3.7/py/lib/python3.7/site-packages (from lime==0.2.0.1->-r ./requirements.txt (line 1)) (4.63.0)
# Requirement already satisfied: scikit-learn>=0.18 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from lime==0.2.0.1->-r ./requirements.txt (line 1)) (1.0.2)
# Collecting scikit-image>=0.12
#   Downloading scikit_image-0.19.2-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (13.5 MB)
# Requirement already satisfied: fonttools>=4.22.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from matplotlib->lime==0.2.0.1->-r ./requirements.txt (line 1)) (4.31.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from matplotlib->lime==0.2.0.1->-r ./requirements.txt (line 1)) (3.0.7)
# Requirement already satisfied: packaging>=20.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from matplotlib->lime==0.2.0.1->-r ./requirements.txt (line 1)) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from matplotlib->lime==0.2.0.1->-r ./requirements.txt (line 1)) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from matplotlib->lime==0.2.0.1->-r ./requirements.txt (line 1)) (1.4.0)
# Requirement already satisfied: pillow>=6.2.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from matplotlib->lime==0.2.0.1->-r ./requirements.txt (line 1)) (9.0.1)
# Requirement already satisfied: cycler>=0.10 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from matplotlib->lime==0.2.0.1->-r ./requirements.txt (line 1)) (0.11.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from scikit-learn>=0.18->lime==0.2.0.1->-r ./requirements.txt (line 1)) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from scikit-learn>=0.18->lime==0.2.0.1->-r ./requirements.txt (line 1)) (1.1.0)
# Collecting tifffile>=2019.7.26
#   Downloading tifffile-2021.11.2-py3-none-any.whl (178 kB)
# Collecting imageio>=2.4.1
#   Downloading imageio-2.16.2-py3-none-any.whl (3.3 MB)
# Collecting PyWavelets>=1.1.1
#   Downloading PyWavelets-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.4 MB)
# Collecting networkx>=2.2
#   Downloading networkx-2.6.3-py3-none-any.whl (1.9 MB)
# Requirement already satisfied: six>=1.5 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from python-dateutil>=2.7->matplotlib->lime==0.2.0.1->-r ./requirements.txt (line 1)) (1.16.0)
# Requirement already satisfied: typing-extensions; python_version < "3.8" in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from kiwisolver>=1.0.1->matplotlib->lime==0.2.0.1->-r ./requirements.txt (line 1)) (4.1.1)
# Building wheels for collected packages: lime
#   Building wheel for lime (setup.py): started
#   Building wheel for lime (setup.py): finished with status 'done'
#   Created wheel for lime: filename=lime-0.2.0.1-py3-none-any.whl size=283845 sha256=4d61b81f128b58e66a38abdf08b4c2ddd4effb4337270084377b8959edacbf87
#   Stored in directory: /root/.cache/pip/wheels/ca/cb/e5/ac701e12d365a08917bf4c6171c0961bc880a8181359c66aa7
# Successfully built lime
# Installing collected packages: tifffile, imageio, PyWavelets, networkx, scikit-image, lime, xgboost
# Successfully installed PyWavelets-1.3.0 imageio-2.16.2 lime-0.2.0.1 networkx-2.6.3 scikit-image-0.19.2 tifffile-2021.11.2 xgboost-1.5.2
# WARNING: You are using pip version 20.1.1; however, version 22.0.4 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=a9029f92-b449-406a-a854-b3dcc7b6fed1' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
